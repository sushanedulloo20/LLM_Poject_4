didn’t, you were all like donkeys. Y ou should not follow rituals and the words
of others blindly. Think for yourselves and understand why you are doing
what you do. If you had given this some thought, you would have recovered
this treasure many months ago. Instead, you wasted your time and money
making offerings to a rock and helping this greedy disciple of mine become
fat and make fools of you. This treasure belongs to all of us. Let’s use it to
keep this road in good repair so everyone can use it and go about their work
in peace.
’
The villagers hung their heads in shame for they realized how foolish they
had been. As for the disciple, he had to clean the cowsheds for many months
to atone for his greed.
'''

# %%
import re

def split_text_into_sentences(text):
    # Regular expression to match sentences ending with '.', '!', '?'
    sentences = re.split(r'(?<=[.!?])\s+', text)
    return sentences

sentences = split_text_into_sentences(text_1)

# %%
sentences=[s.strip() for s in sentences]

# %%
def group_sentences_into_paragraphs(sentences, group_size=15):
    # Group the sentences into paragraphs of 'group_size' sentences each
    paragraphs = [' '.join(sentences[i:i+group_size]) for i in range(0, len(sentences), group_size)]
    return paragraphs

# Group sentences into paragraphs of 20 sentences each
paragraphs = group_sentences_into_paragraphs(sentences)

# Output the paragraphs

# %%
paragraphs
# Out:
# ['Ajji was on an outing with her daughter and daughter-in-law, Sumati and\nSubhadra. One lived in Bangalore and the other in Mumbai. They were\nreturning the next day as they had used up all the leaves their offices had\ngiven. The children would remain at Shiggaon though, with their\ngrandparents. Everyone was looking forward to this stage of the holidays. The\nchildren because there would be no parents telling them what to do, to Ajji’s\ndelicious food and to fun outings with Ajja. The grandparents, too, were\nlooking forward to having the children to themselves. The rest of the year it\nwas only the two of them in the house. As Ajji walked with the two younger women, they talked about how\ndifficult it was for them to manage their office work and the children. Ajji\nlistened silently. Then Sumati said,\n‘But they are so good when they are with\nyou, Amma. How do you manage them so well?’ Subhadra nodded. ‘I have\nread so many books and articles to find out about this, but nothing works the\nway it is written in books. ’\nNow Ajji said,\n‘Do not always go by what you read in books. Learn to use\nyour life’s experiences, read between the lines.',
#  '’ Then she grinned and said,\n‘Otherwise you will become like the people in the story about the donkey and\nthe stick!’\nSumati and Subhadra forgot they were at the temple and clamoured\ntogether,\n‘What is this story? Tell us!’ Ajji shook her head. ‘Now you are\nbehaving like children. But you are my children after all. All right, come join\nus at night when I tell today’s story. ’\nThat night the two mothers were the first to appear to listen to the stories. The children were surprised to see their mums, and Ajji started her story. Aruna Marg was a busy road. It connected a number of villages to each other\nand many people, animals and carts used it every day. Walking along that\nroad, a group of students discovered a rock which no one had bothered to look\nat in many years. ‘Look!’ they told each other in excitement,\n‘there is\nsomething written on the rock. What can it mean?’\nThey called out to their teacher. When they examined the rock carefully,\nthey found the markings were actually little drawings. One showed a stick,\nand the other a donkey. By now a large crowd had gathered.',
#  'Everyone was puzzled. What could\nthese strange drawings mean, they asked, scratching their heads. They\ndecided to go to the ashram of a wise sage nearby and ask him. But when they\ntrooped into the ashram, they found to their disappointment that the sage had\ngone on a long pilgrimage. Only his young disciple was there, looking after\nthe cows and calves. They asked the disciple if he could throw some light on the strange\ndrawings. Now this young man was not very bright. But like many foolish\npeople he loved to put on an air of learning and pretend to be very clever. He\nexamined the drawings carefully and minutely. Then he proclaimed,\n‘It is\nvery simple. This is the drawing of a magic stick. The man with the stick is\nthe hero of this place. He died protecting this village centuries back. Each\nperson using this road must worship the rock and make an offering to it. The\none who ignores it will become a donkey!’\nThe villagers were astonished to hear this strange explanation.',
#  'But they\nwere devout people and on that very day they set up a shrine around the rock. They installed the foolish disciple as head priest in charge of taking offerings\nfrom passing travellers. The disciple was pleased with his brainwave. Of\ncourse he did not know what the silly drawings meant, but he no longer had to\nrun after calves and get kicked by angry cows in the ashram! He could sit by\nthe rock the whole day, taking his pick of the offerings to the rock and mutter\na few mumbo-jumbo prayers. His happiness lasted a few months—till the wise old sage returned to the\nashram. The old sage was annoyed to find his disciple missing and his\nbeloved animals roaming around, uncared for. Then he looked into the\ndistance and saw a large crowd gathered by the road. He went to investigate,\nand found his missing disciple there, looking happy and well fed, busy\naccepting offerings for a rock. He stood watching for a while. Then he walked\nup to the rock and closely examined the pictures. Without saying a word, he\npicked up a stout iron rod and, to the astonishment of the gathered crowd,\nstarted moving the rock. Many came forward to help him and when they had\nbeen able to move the rock, they found a pot of gold under it! The sage said to the people gathered around him: ‘The pictures meant you\nhad to move the rock with an iron rod and find the hidden money. If you\ndidn’t, you were all like donkeys.',
#  'Y ou should not follow rituals and the words\nof others blindly. Think for yourselves and understand why you are doing\nwhat you do. If you had given this some thought, you would have recovered\nthis treasure many months ago. Instead, you wasted your time and money\nmaking offerings to a rock and helping this greedy disciple of mine become\nfat and make fools of you. This treasure belongs to all of us. Let’s use it to\nkeep this road in good repair so everyone can use it and go about their work\nin peace. ’\nThe villagers hung their heads in shame for they realized how foolish they\nhad been. As for the disciple, he had to clean the cowsheds for many months\nto atone for his greed. ']

# %%
from together import Together

# %%
API_KEY="2790f2e2cb0b9d107fbe0398eaee980bdbc8b3fe23aec2b3bf182e1fd6a81e3d"
client=Together(api_key=API_KEY)

# %%
def generate_prompt(text,context):
  output=f'''
Given is the previous story:{context}
Given below is current story.You need to divide the current story into small chunks.For each chunk label them with their speaker and one of the following emotion [sadness, happiness, fear, anger, surprise , disgust or neutral] ,the speaker includes narator also .Divide into as many chunks as possible.Strictly Make sure you dont mix the sentence chunks of the characters dialogue and the narator dialogues.\nFor example sentence: he said "I am good" the sentence should be divided as he said and "I am good"\n.Emotion should be selected strictly from [sadness, happiness, fear, anger, surprise , disgust or neutral] directly without providing any reasoning,just provide one of the emotion label given to you directly.Do not miss any sentence strictly.\nSTORY:\n{text}.\n The output should be strictly in the form of list of json with each json having keys text_chunk,speaker and emotion.Nothing else should be provided except the json.
The output format:
[
  {{
    text_chunk:"sentence1"
    speaker:"speaker1"
    emotion:"emotion1"

  }}
  ,
  {{
    text_chunk:"sentence2"
    speaker:"speaker2"
    emotion:"emotion2"

  }}
]
  '''
  return output

# %%
print(generate_prompt(paragraphs[0],paragraphs[1]))
# Out:
# Given is the previous story:’ Then she grinned and said,
# ‘Otherwise you will become like the people in the story about the donkey and
# the stick!’
# Sumati and Subhadra forgot they were at the temple and clamoured
# together,
# ‘What is this story? Tell us!’ Ajji shook her head. ‘Now you are
# behaving like children. But you are my children after all. All right, come join
# us at night when I tell today’s story. ’
# That night the two mothers were the first to appear to listen to the stories. The children were surprised to see their mums, and Ajji started her story. Aruna Marg was a busy road. It connected a number of villages to each other
# and many people, animals and carts used it every day. Walking along that
# road, a group of students discovered a rock which no one had bothered to look
# at in many years. ‘Look!’ they told each other in excitement,
# ‘there is
# something written on the rock. What can it mean?’
# They called out to their teacher. When they examined the rock carefully,
# they found the markings were actually little drawings. One showed a stick,
# and the other a donkey. By now a large crowd had gathered.
# Given below is current story.You need to divide the current story into small chunks.For each chunk label them with their speaker and one of the following emotion [sadness, happiness, fear, anger, surprise , disgust or neutral] ,the speaker includes narator also .Divide into as many chunks as possible.Strictly Make sure you dont mix the sentence chunks of the characters dialogue and the narator dialogues.
# For example sentence: he said "I am good" the sentence should be divided as he said and "I am good"
# .Emotion should be selected strictly from [sadness, happiness, fear, anger, surprise , disgust or neutral] directly without providing any reasoning,just provide one of the emotion label given to you directly.Do not miss any sentence strictly.
# STORY:
# Ajji was on an outing with her daughter and daughter-in-law, Sumati and
# Subhadra. One lived in Bangalore and the other in Mumbai. They were
# returning the next day as they had used up all the leaves their offices had
# given. The children would remain at Shiggaon though, with their
# grandparents. Everyone was looking forward to this stage of the holidays. The
# children because there would be no parents telling them what to do, to Ajji’s
# delicious food and to fun outings with Ajja. The grandparents, too, were
# looking forward to having the children to themselves. The rest of the year it
# was only the two of them in the house. As Ajji walked with the two younger women, they talked about how
# difficult it was for them to manage their office work and the children. Ajji
# listened silently. Then Sumati said,
# ‘But they are so good when they are with
# you, Amma. How do you manage them so well?’ Subhadra nodded. ‘I have
# read so many books and articles to find out about this, but nothing works the
# way it is written in books. ’
# Now Ajji said,
# ‘Do not always go by what you read in books. Learn to use
# your life’s experiences, read between the lines..
#  The output should be strictly in the form of list of json with each json having keys text_chunk,speaker and emotion.Nothing else should be provided except the json.
# The output format:
# [
#   {
#     text_chunk:"sentence1"
#     speaker:"speaker1"
#     emotion:"emotion1"
#
#   }
#   ,
#   {
#     text_chunk:"sentence2"
#     speaker:"speaker2"
#     emotion:"emotion2"
#
#   }
# ]

# %%
def generate_response(model,client,text,context):
  prompt=generate_prompt(text,context)
  response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "assistant", "content": "You are an expert at predicting  speakers and emotions from a given text."},
            {"role": "user", "content": prompt}
        ]

  )
  response = response.choices[0].message.content.strip()
  return response

# %%
MODEL_NAME='google/gemma-2-27b-it'

# %%
response=generate_response(MODEL_NAME,client,paragraphs[3],paragraphs[2])

# %%
paragraphs[3]
# Out:
# 'But they\nwere devout people and on that very day they set up a shrine around the rock. They installed the foolish disciple as head priest in charge of taking offerings\nfrom passing travellers. The disciple was pleased with his brainwave. Of\ncourse he did not know what the silly drawings meant, but he no longer had to\nrun after calves and get kicked by angry cows in the ashram! He could sit by\nthe rock the whole day, taking his pick of the offerings to the rock and mutter\na few mumbo-jumbo prayers. His happiness lasted a few months—till the wise old sage returned to the\nashram. The old sage was annoyed to find his disciple missing and his\nbeloved animals roaming around, uncared for. Then he looked into the\ndistance and saw a large crowd gathered by the road. He went to investigate,\nand found his missing disciple there, looking happy and well fed, busy\naccepting offerings for a rock. He stood watching for a while. Then he walked\nup to the rock and closely examined the pictures. Without saying a word, he\npicked up a stout iron rod and, to the astonishment of the gathered crowd,\nstarted moving the rock. Many came forward to help him and when they had\nbeen able to move the rock, they found a pot of gold under it! The sage said to the people gathered around him: ‘The pictures meant you\nhad to move the rock with an iron rod and find the hidden money. If you\ndidn’t, you were all like donkeys.'

# %%
print(response)
# Out:
# [
#   {
#     "text_chunk": "But they were devout people and on that very day they set up a shrine around the rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "They installed the foolish disciple as head priest in charge of taking offerings from passing travellers.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The disciple was pleased with his brainwave.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Of course he did not know what the silly drawings meant, but he no longer had to run after calves and get kicked by angry cows in the ashram!",
#     "speaker": "narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "He could sit by the rock the whole day, taking his pick of the offerings to the rock and mutter a few mumbo-jumbo prayers.",
#     "speaker": "narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "His happiness lasted a few months—till the wise old sage returned to the ashram.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The old sage was annoyed to find his disciple missing and his beloved animals roaming around, uncared for.",
#     "speaker": "narrator",
#     "emotion": "anger"
#   },
#   {
#     "text_chunk": "Then he looked into the distance and saw a large crowd gathered by the road.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He went to investigate, and found his missing disciple there, looking happy and well fed, busy accepting offerings for a rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He stood watching for a while.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Then he walked up to the rock and closely examined the pictures.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Without saying a word, he picked up a stout iron rod and, to the astonishment of the gathered crowd, started moving the rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Many came forward to help him and when they had been able to move the rock, they found a pot of gold under it!",
#     "speaker": "narrator",
#     "emotion": "surprise"
#   },
#   {
#     "text_chunk": "The sage said to the people gathered around him: ‘The pictures meant you had to move the rock with an iron rod and find the hidden money.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "If you didn’t, you were all like donkeys..",
#     "speaker": "sage",
#     "emotion": "neutral"
#   }
# ]

# %%
import time
def generate_annotations(paragraphs):
  time.sleep(10)
  answer=[]
  for i in range(len(paragraphs)):
    if i==0:
      response=generate_response(MODEL_NAME,client,paragraphs[0],'')
      answer.append(response)
    else:
      response=generate_response(MODEL_NAME,client,paragraphs[i],paragraphs[i-1])
      answer.append(response)
  return answer

# %%
ans=generate_annotations(paragraphs)

# %%
for a in ans:
  print(a)
# Out:
# [
#   {
#     "text_chunk": "Ajji was on an outing with her daughter and daughter-in-law, Sumati and Subhadra.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "One lived in Bangalore and the other in Mumbai.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "They were returning the next day as they had used up all the leaves their offices had given.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The children would remain at Shiggaon though, with their grandparents.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Everyone was looking forward to this stage of the holidays.",
#     "speaker": "Narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "The children because there would be no parents telling them what to do, to Ajji’s delicious food and to fun outings with Ajja.",
#     "speaker": "Narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "The grandparents, too, were looking forward to having the children to themselves.",
#     "speaker": "Narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "The rest of the year it was only the two of them in the house.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "As Ajji walked with the two younger women, they talked about how difficult it was for them to manage their office work and the children.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Ajji listened silently.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Then Sumati said,",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘But they are so good when they are with you, Amma.",
#     "speaker": "Sumati",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "How do you manage them so well?’",
#     "speaker": "Sumati",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Subhadra nodded.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘I have read so many books and articles to find out about this, but nothing works the way it is written in books.",
#     "speaker": "Subhadra",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "’",
#     "speaker": "Subhadra",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Now Ajji said,",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘Do not always go by what you read in books.",
#     "speaker": "Ajji",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Learn to use your life’s experiences, read between the lines..",
#     "speaker": "Ajji",
#     "emotion": "neutral"
#   }
# ]
# [
#   {
#     "text_chunk": "Then she grinned and said,",
#     "speaker": "Ajji",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "‘Otherwise you will become like the people in the story about the donkey and the stick!’",
#     "speaker": "Ajji",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Sumati and Subhadra forgot they were at the temple and clamoured together,",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘What is this story? Tell us!’",
#     "speaker": "Sumati and Subhadra",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "Ajji shook her head.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘Now you are behaving like children.",
#     "speaker": "Ajji",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "But you are my children after all.",
#     "speaker": "Ajji",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "All right, come join us at night when I tell today’s story.",
#     "speaker": "Ajji",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "That night the two mothers were the first to appear to listen to the stories.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The children were surprised to see their mums, and Ajji started her story.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Aruna Marg was a busy road.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "It connected a number of villages to each other and many people, animals and carts used it every day.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Walking along that road, a group of students discovered a rock which no one had bothered to look at in many years.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘Look!’",
#     "speaker": "Students",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "they told each other in excitement,",
#     "speaker": "Students",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "‘there is something written on the rock.",
#     "speaker": "Students",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "What can it mean?’",
#     "speaker": "Students",
#     "emotion": "surprise"
#   },
#   {
#     "text_chunk": "They called out to their teacher.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "When they examined the rock carefully, they found the markings were actually little drawings.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "One showed a stick, and the other a donkey.",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "By now a large crowd had gathered..",
#     "speaker": "Narrator",
#     "emotion": "neutral"
#   }
# ]
# [
#   {
#     "text_chunk": "Everyone was puzzled.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "What could these strange drawings mean, they asked, scratching their heads.",
#     "speaker": "villagers",
#     "emotion": "surprise"
#   },
#   {
#     "text_chunk": "They decided to go to the ashram of a wise sage nearby and ask him.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "But when they trooped into the ashram, they found to their disappointment that the sage had gone on a long pilgrimage.",
#     "speaker": "narrator",
#     "emotion": "disappointment"
#   },
#   {
#     "text_chunk": "Only his young disciple was there, looking after the cows and calves.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "They asked the disciple if he could throw some light on the strange drawings.",
#     "speaker": "villagers",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Now this young man was not very bright.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "But like many foolish people he loved to put on an air of learning and pretend to be very clever.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He examined the drawings carefully and minutely.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Then he proclaimed,",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "‘It is very simple.",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "This is the drawing of a magic stick.",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The man with the stick is the hero of this place.",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He died protecting this village centuries back.",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Each person using this road must worship the rock and make an offering to it.",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The one who ignores it will become a donkey!’",
#     "speaker": "disciple",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The villagers were astonished to hear this strange explanation.",
#     "speaker": "narrator",
#     "emotion": "surprise"
#   }
# ]
# [
#   {
#     "text_chunk": "But they were devout people and on that very day they set up a shrine around the rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "They installed the foolish disciple as head priest in charge of taking offerings from passing travellers.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The disciple was pleased with his brainwave.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Of course he did not know what the silly drawings meant, but he no longer had to run after calves and get kicked by angry cows in the ashram!",
#     "speaker": "narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "He could sit by the rock the whole day, taking his pick of the offerings to the rock and mutter a few mumbo-jumbo prayers.",
#     "speaker": "narrator",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "His happiness lasted a few months—till the wise old sage returned to the ashram.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "The old sage was annoyed to find his disciple missing and his beloved animals roaming around, uncared for.",
#     "speaker": "narrator",
#     "emotion": "anger"
#   },
#   {
#     "text_chunk": "Then he looked into the distance and saw a large crowd gathered by the road.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He went to investigate, and found his missing disciple there, looking happy and well fed, busy accepting offerings for a rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "He stood watching for a while.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Then he walked up to the rock and closely examined the pictures.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Without saying a word, he picked up a stout iron rod and, to the astonishment of the gathered crowd, started moving the rock.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Many came forward to help him and when they had been able to move the rock, they found a pot of gold under it!",
#     "speaker": "narrator",
#     "emotion": "surprise"
#   },
#   {
#     "text_chunk": "The sage said to the people gathered around him: ‘The pictures meant you had to move the rock with an iron rod and find the hidden money.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "If you didn’t, you were all like donkeys..",
#     "speaker": "sage",
#     "emotion": "neutral"
#   }
# ]
# [
#   {
#     "text_chunk": "You should not follow rituals and the words of others blindly.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Think for yourselves and understand why you are doing what you do.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "If you had given this some thought, you would have recovered this treasure many months ago.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Instead, you wasted your time and money making offerings to a rock and helping this greedy disciple of mine become fat and make fools of you.",
#     "speaker": "sage",
#     "emotion": "anger"
#   },
#   {
#     "text_chunk": "This treasure belongs to all of us.",
#     "speaker": "sage",
#     "emotion": "neutral"
#   },
#   {
#     "text_chunk": "Let’s use it to keep this road in good repair so everyone can use it and go about their work in peace.",
#     "speaker": "sage",
#     "emotion": "happiness"
#   },
#   {
#     "text_chunk": "The villagers hung their heads in shame for they realized how foolish they had been.",
#     "speaker": "narrator",
#     "emotion": "sadness"
#   },
#   {
#     "text_chunk": "As for the disciple, he had to clean the cowsheds for many months to atone for his greed.",
#     "speaker": "narrator",
#     "emotion": "neutral"
#   }
# ]

# %%
import json
dic=json.loads(ans[0])

# %%
dic
# Out:
# [{'text_chunk': 'Ajji was on an outing with her daughter and daughter-in-law, Sumati and Subhadra.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One lived in Bangalore and the other in Mumbai.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They were returning the next day as they had used up all the leaves their offices had given.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The children would remain at Shiggaon though, with their grandparents.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Everyone was looking forward to this stage of the holidays.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The children because there would be no parents telling them what to do, to Ajji’s delicious food and to fun outings with Ajja.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The grandparents, too, were looking forward to having the children to themselves.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The rest of the year it was only the two of them in the house.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'As Ajji walked with the two younger women, they talked about how difficult it was for them to manage their office work and the children.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ajji listened silently.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then Sumati said,',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘But they are so good when they are with you, Amma.',
#   'speaker': 'Sumati',
#   'emotion': 'happiness'},
#  {'text_chunk': 'How do you manage them so well?’',
#   'speaker': 'Sumati',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Subhadra nodded.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘I have read so many books and articles to find out about this, but nothing works the way it is written in books.',
#   'speaker': 'Subhadra',
#   'emotion': 'neutral'},
#  {'text_chunk': '’', 'speaker': 'Subhadra', 'emotion': 'neutral'},
#  {'text_chunk': 'Now Ajji said,', 'speaker': 'Narrator', 'emotion': 'neutral'},
#  {'text_chunk': '‘Do not always go by what you read in books.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Learn to use your life’s experiences, read between the lines..',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'}]

# %%
def convert_to_json(ans):
  final=[]
  for a in ans:
    dic=json.loads(a)
    for d in dic:
      final.append(d)
  return final

# %%
convert_to_json(ans)
# Out:
# [{'text_chunk': 'Ajji was on an outing with her daughter and daughter-in-law, Sumati and Subhadra.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One lived in Bangalore and the other in Mumbai.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They were returning the next day as they had used up all the leaves their offices had given.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The children would remain at Shiggaon though, with their grandparents.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Everyone was looking forward to this stage of the holidays.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The children because there would be no parents telling them what to do, to Ajji’s delicious food and to fun outings with Ajja.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The grandparents, too, were looking forward to having the children to themselves.',
#   'speaker': 'Narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The rest of the year it was only the two of them in the house.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'As Ajji walked with the two younger women, they talked about how difficult it was for them to manage their office work and the children.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ajji listened silently.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then Sumati said,',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘But they are so good when they are with you, Amma.',
#   'speaker': 'Sumati',
#   'emotion': 'happiness'},
#  {'text_chunk': 'How do you manage them so well?’',
#   'speaker': 'Sumati',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Subhadra nodded.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘I have read so many books and articles to find out about this, but nothing works the way it is written in books.',
#   'speaker': 'Subhadra',
#   'emotion': 'neutral'},
#  {'text_chunk': '’', 'speaker': 'Subhadra', 'emotion': 'neutral'},
#  {'text_chunk': 'Now Ajji said,', 'speaker': 'Narrator', 'emotion': 'neutral'},
#  {'text_chunk': '‘Do not always go by what you read in books.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Learn to use your life’s experiences, read between the lines..',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then she grinned and said,',
#   'speaker': 'Ajji',
#   'emotion': 'happiness'},
#  {'text_chunk': '‘Otherwise you will become like the people in the story about the donkey and the stick!’',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Sumati and Subhadra forgot they were at the temple and clamoured together,',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘What is this story? Tell us!’',
#   'speaker': 'Sumati and Subhadra',
#   'emotion': 'happiness'},
#  {'text_chunk': 'Ajji shook her head.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Now you are behaving like children.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But you are my children after all.',
#   'speaker': 'Ajji',
#   'emotion': 'happiness'},
#  {'text_chunk': 'All right, come join us at night when I tell today’s story.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'That night the two mothers were the first to appear to listen to the stories.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The children were surprised to see their mums, and Ajji started her story.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Aruna Marg was a busy road.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'It connected a number of villages to each other and many people, animals and carts used it every day.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Walking along that road, a group of students discovered a rock which no one had bothered to look at in many years.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Look!’', 'speaker': 'Students', 'emotion': 'happiness'},
#  {'text_chunk': 'they told each other in excitement,',
#   'speaker': 'Students',
#   'emotion': 'happiness'},
#  {'text_chunk': '‘there is something written on the rock.',
#   'speaker': 'Students',
#   'emotion': 'happiness'},
#  {'text_chunk': 'What can it mean?’',
#   'speaker': 'Students',
#   'emotion': 'surprise'},
#  {'text_chunk': 'They called out to their teacher.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'When they examined the rock carefully, they found the markings were actually little drawings.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One showed a stick, and the other a donkey.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'By now a large crowd had gathered..',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Everyone was puzzled.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'What could these strange drawings mean, they asked, scratching their heads.',
#   'speaker': 'villagers',
#   'emotion': 'surprise'},
#  {'text_chunk': 'They decided to go to the ashram of a wise sage nearby and ask him.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But when they trooped into the ashram, they found to their disappointment that the sage had gone on a long pilgrimage.',
#   'speaker': 'narrator',
#   'emotion': 'disappointment'},
#  {'text_chunk': 'Only his young disciple was there, looking after the cows and calves.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They asked the disciple if he could throw some light on the strange drawings.',
#   'speaker': 'villagers',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Now this young man was not very bright.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But like many foolish people he loved to put on an air of learning and pretend to be very clever.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He examined the drawings carefully and minutely.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then he proclaimed,',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘It is very simple.',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'This is the drawing of a magic stick.',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The man with the stick is the hero of this place.',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He died protecting this village centuries back.',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Each person using this road must worship the rock and make an offering to it.',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The one who ignores it will become a donkey!’',
#   'speaker': 'disciple',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The villagers were astonished to hear this strange explanation.',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'But they were devout people and on that very day they set up a shrine around the rock.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They installed the foolish disciple as head priest in charge of taking offerings from passing travellers.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The disciple was pleased with his brainwave.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Of course he did not know what the silly drawings meant, but he no longer had to run after calves and get kicked by angry cows in the ashram!',
#   'speaker': 'narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'He could sit by the rock the whole day, taking his pick of the offerings to the rock and mutter a few mumbo-jumbo prayers.',
#   'speaker': 'narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'His happiness lasted a few months—till the wise old sage returned to the ashram.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The old sage was annoyed to find his disciple missing and his beloved animals roaming around, uncared for.',
#   'speaker': 'narrator',
#   'emotion': 'anger'},
#  {'text_chunk': 'Then he looked into the distance and saw a large crowd gathered by the road.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He went to investigate, and found his missing disciple there, looking happy and well fed, busy accepting offerings for a rock.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He stood watching for a while.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then he walked up to the rock and closely examined the pictures.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Without saying a word, he picked up a stout iron rod and, to the astonishment of the gathered crowd, started moving the rock.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Many came forward to help him and when they had been able to move the rock, they found a pot of gold under it!',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'The sage said to the people gathered around him: ‘The pictures meant you had to move the rock with an iron rod and find the hidden money.',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'If you didn’t, you were all like donkeys..',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'You should not follow rituals and the words of others blindly.',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Think for yourselves and understand why you are doing what you do.',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'If you had given this some thought, you would have recovered this treasure many months ago.',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Instead, you wasted your time and money making offerings to a rock and helping this greedy disciple of mine become fat and make fools of you.',
#   'speaker': 'sage',
#   'emotion': 'anger'},
#  {'text_chunk': 'This treasure belongs to all of us.',
#   'speaker': 'sage',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Let’s use it to keep this road in good repair so everyone can use it and go about their work in peace.',
#   'speaker': 'sage',
#   'emotion': 'happiness'},
#  {'text_chunk': 'The villagers hung their heads in shame for they realized how foolish they had been.',
#   'speaker': 'narrator',
#   'emotion': 'sadness'},
#  {'text_chunk': 'As for the disciple, he had to clean the cowsheds for many months to atone for his greed.',
#   'speaker': 'narrator',
#   'emotion': 'neutral
sari to wear the next day and what to do with our money. I am too fat to even
dig, like I did when I found the treasure!’
Ramu smiled and hugged his wife.
‘We’ll go back to our village, and to our
old ways. We will work hard like we did once, and we will help everyone
around us. Maybe that will make Lakshmi come back to us one day. And even
if she doesn’t, we will try and be happy with what we have.
’
So Ramu and his family went back to their old home. And do you know
what? They did live happily ever after!
The gods watched what was happening with Ramu and Rani from the heavens
as Lakshmi entered and then left their house. They had to agree with her—if
the people of the house she entered became nasty, then what could she do
except leave, and hope they saw the error of their ways?
'''

# %%
def pipeline(text):
  sentences = split_text_into_sentences(text)
  paragraphs = group_sentences_into_paragraphs(sentences)
  ans=generate_annotations(paragraphs)
  return convert_to_json(ans)

# %%
output=pipeline(text_2)

# %%
output
# Out:
# [{'text_chunk': 'Vishnu Kaka’s grandchildren had come to visit him.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Vishnu Kaka was a very good friend of Ajja’s.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They had lived next door to each other for years.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Unfortunately, his wife V asanthi Kaki had died a few years back.',
#   'speaker': 'Narrator',
#   'emotion': 'sadness'},
#  {'text_chunk': 'Though there was a cook, his grandchildren—Sharan, Suma and Divya—always preferred to eat in Ajji’s house, which Ajji also welcomed.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'With seven hungry children to feed, Ajji realized telling a story would be a good way to keep them quiet till the food got cooked.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ajji started the story while peeling the cucumbers.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Did you know that sometimes even the gods in heaven can get into an argument?',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'That’s what happened once when Lakshmi, the goddess of wealth, found herself cornered by all the other gods.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Together, they accused her of one thing—that she never stayed in one place for too long!',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘No sooner are you comfortably settled in one house, do you decide to leave it, and off you go elsewhere!’ they said to her.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Lakshmi sniffed and said,',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘That’s not true.', 'speaker': 'Ajji', 'emotion': 'neutral'},
#  {'text_chunk': 'I stay in a house as long as I am welcome.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'If people think ahead, work sincerely and spend money wisely, I stay with them forever.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Unfortunately often when I am in one place for a while, people behave strangely, and I have no choice but to leave..',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The other gods pooh-poohed this and refused to believe her.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Poor Lakshmi decided she needed to show them proof of what she had just said.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Here is what she did to show that she was correct.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Remember, many human years make only a second in god years.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'So what took years to happen on earth, the gods could see in only a few minutes.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ramu and Rani were farmers.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They worked hard in their fields and earned enough money to feed their children and meet their other needs.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They were not rich and sometimes had to make do with fewer new clothes and not very nice food.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One day, Rani was digging a corner of her garden in order to plant a tree.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'As she dug deeper, there was a loud clang!',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Her shovel had hit something metallic hidden underground.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Excited, she dug faster, till she pulled out a large metal box.',
#   'speaker': 'narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'When she opened it she could not believe her eyes.',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'It was filled with gold and silver jewels!',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'For a while Rani stood dumbstruck..',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'Then she did a happy whoop and ran home with the box under her arm.',
#   'speaker': 'narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': '‘Ramu, Ramu, see what I found buried in our garden!’',
#   'speaker': 'Rani',
#   'emotion': 'happiness'},
#  {'text_chunk': 'she yelled', 'speaker': 'narrator', 'emotion': 'neutral'},
#  {'text_chunk': 'Ramu was writing up the accounts for the month, and for a while paid no attention to his wife.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Only when she came up to him and did a happy jig around him did he look up.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Imagine how his mouth fell open in surprise when he saw the box of jewels.',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'Soon Ramu and Rani were the richest people in the village.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They stopped going to work—after all, what was the need, they told each other.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Why work in the hot sun when they had piles of money at home?',
#   'speaker': 'Ramu',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They left their small cottage and moved into the biggest house in the village.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They had servants who worked day and night doing every small job, so the two did not need to lift even a finger.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'There was a cook who cooked delicious meals, a person to serve it, another just to clean shoes and one person to even fan Ramu as he sat on his bed the whole day and gossiped with his newfound friends.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then Ramu decided village life was too boring and they moved to the big city.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'There they had another big house, more servants and lots of fun at various parties.',
#   'speaker': 'narrator',
#   'emotion': 'happiness'},
#  {'text_chunk': 'Slowly they forgot the good things that had once made them a well-loved family.',
#   'speaker': 'narrator',
#   'emotion': 'sadness'},
#  {'text_chunk': 'They forgot to work hard, to help others in their need, or to just be nice people.',
#   'speaker': 'narrator',
#   'emotion': 'sadness'},
#  {'text_chunk': 'They thought that with money they could buy anything,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'including respect.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They behaved rudely to others.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They spent more and more money on clothes and parties, and as they did no work at all, the money started dwindling.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They started borrowing from others which they soon could not pay back.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One day, Ramu looked sadly at his account book.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'It was now filled with numbers that showed he only needed to pay others; there was hardly anything left for himself.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'In a heavy voice he called out to his wife,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Rani dear, the good days are over.',
#   'speaker': 'Ramu',
#   'emotion': 'sadness'},
#  {'text_chunk': 'I think we forgot to be the kind of people Goddess Lakshmi likes.',
#   'speaker': 'Ramu',
#   'emotion': 'sadness'},
#  {'text_chunk': 'She has gone elsewhere, and we are left with nothing.',
#   'speaker': 'Ramu',
#   'emotion': 'sadness'},
#  {'text_chunk': '’', 'speaker': 'Ramu', 'emotion': 'sadness'},
#  {'text_chunk': 'Rani stood silently for a while, then replied,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Never mind, Ramu.', 'speaker': 'Rani', 'emotion': 'neutral'},
#  {'text_chunk': 'We have learnt our lesson.',
#   'speaker': 'Rani',
#   'emotion': 'neutral'},
#  {'text_chunk': 'I now think of the days when I would work all day long and go to sleep a tired person and sleep soundly.',
#   'speaker': 'Rani',
#   'emotion': 'neutral'},
#  {'text_chunk': 'I would fall into a deep slumber as soon as I Iay down on the bed.',
#   'speaker': 'Rani',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Now I lie awake all night, wondering which sari to wear the next day and what to do with our money.',
#   'speaker': 'Rani',
#   'emotion': 'neutral'},
#  {'text_chunk': 'I am too fat to even dig, like I did when I found the treasure!’,',
#   'speaker': 'Rani',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ramu smiled and hugged his wife..',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘We’ll go back to our village, and to our old ways.',
#   'speaker': 'Ramu',
#   'emotion': 'happiness'},
#  {'text_chunk': 'We will work hard like we did once, and we will help everyone around us.',
#   'speaker': 'Ramu',
#   'emotion': 'happiness'},
#  {'text_chunk': 'Maybe that will make Lakshmi come back to us one day.',
#   'speaker': 'Ramu',
#   'emotion': 'neutral'},
#  {'text_chunk': 'And even if she doesn’t, we will try and be happy with what we have.',
#   'speaker': 'Ramu',
#   'emotion': 'happiness'},
#  {'text_chunk': 'So Ramu and his family went back to their old home.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'And do you know what?',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '
once our family was very rich. Though we lost a lot of our money, much of it
was also buried here, in this field by one ancestor, to keep it safe from
robbers. Then people forgot about it for years and years. My husband found a
clue to the location of the hidden treasure just a few days back. Why do you
think I am digging this hard earth? Not to sow seeds, oh no, that’s just what
everyone thinks. I am actually looking for hidden treasure!’
The thief was stunned. He felt this woman was really innocent, giving such
important information to a stranger. He thought, why should I not take
advantage of this situation? Here he was, hoping to steal a few coins from the
temple, and this woman was telling him about hidden treasure! He replied in a
very humble way,
‘Y es sister, I understand; after all it is your family treasure.
Only you should get it.
’ He pretended to walk away, and went and hid himself
a little way down the road.
Night fell; Kavery packed up her tools and headed home. The temple, too,
emptied out and the priest locked it up for the night. Then at midnight, when
all was quiet and the night creatures were coming out of their homes, the thief
crept into the field.
All night he dug and dug, looking for treasure, but of course there was no
sign of it as there never had been any treasure to begin with! By the time
dawn broke he realized Kavery had made a fool of him and all he could do
now was get away from the field fast.
When Kavery reached the field she grinned to herself. Just as she had
expected, the thief had spent the night digging up the land nicely for her. All
she needed to do now was sow the seeds. She worked hard in the field for the
next few months and managed to grow a good crop. She sold those and finally
they had some money. With a part of this money Kavery bought some
jewellery.
'''

# %%
output_3=pipeline(text_3)
output_3
# Out:
# [{'text_chunk': 'The children had gone with their Ajja to the paddy fields that morning.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They were all city kids and did not know a thing about farming!',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'On the way, Anand was surprised to see a bird’s nest on top of the tree.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He said to Ajja,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘I wonder how birds decide where and how to make their nests!’',
#   'speaker': 'Anand',
#   'emotion': 'surprise'},
#  {'text_chunk': 'Ajja said,', 'speaker': 'narrator', 'emotion': 'neutral'},
#  {'text_chunk': '‘The straw in the nest is from the paddy field.',
#   'speaker': 'Ajja',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Do you know, farming helps human beings as well as birds?’',
#   'speaker': 'Ajja',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Krishna replied,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Ajja, I thought wheat and rice can be just plucked from trees, like mangoes.',
#   'speaker': 'Krishna',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But today I realized there is so much work in farming.',
#   'speaker': 'Krishna',
#   'emotion': 'neutral'},
#  {'text_chunk': '’', 'speaker': 'Krishna', 'emotion': 'neutral'},
#  {'text_chunk': 'That afternoon, after lunch, when they gathered around Ajji for the day’s story, she looked sharply at the children.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They had enjoyed learning about farming activities like cleaning seeds and separating the straw from paddy.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'In the city everything came from the supermarket, but here they had seen how things were really produced.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ajji said,', 'speaker': 'narrator', 'emotion': 'neutral'},
#  {'text_chunk': '‘Farming is very important.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'If farmers do not grow any food, what will we all eat?’',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Anand said thoughtfully,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘If farmers do such important work, why are they so poor?’',
#   'speaker': 'Anand',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘That’s true, my dear, ’',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Ajji sighed, fanning herself.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Of course there are rich farmers too, people who own lots of land.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But many in our country till small pieces of land, and so make less money.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': '’', 'speaker': 'Ajji', 'emotion': 'neutral'},
#  {'text_chunk': 'Then seeing the kids’ crestfallen faces, she put down her fan, sat up and said,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘But I can tell you of a poor farmer woman who did not remain very poor.',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': 'All due to her sharp wit!’',
#   'speaker': 'Ajji',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Tell Ajji! ', 'speaker': 'narrator', 'emotion': 'neutral'},
#  {'text_chunk': 'Do tell!', 'speaker': 'kids', 'emotion': 'happiness'},
#  {'text_chunk': 'So Ajji started her story.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Kavery’s lazy husband annoyed her no end.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'There she was working like a donkey in the fields, ploughing and watering and tending a hard, dry piece of land, while her husband snored away happily at home!',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Why, once when a stranger came asking for some food and water, he just pointed towards the kitchen and went back to sleep.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The stranger, thankfully, was an honest man and took only enough for himself and his horse.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Not that there was much to steal in Kavery’s little house.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'They were poor farmers with only a patch of land where nothing seemed to grow.',
#   'speaker': 'narrator',
#   'emotion': 'sadness'},
#  {'text_chunk': 'Somehow Kavery tilled the land, did some odd jobs in the neighbourhood, and made ends meet.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The land was right next to a temple.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'On some days her husband would come along with her on the pretext of helping her, but no sooner would her back be turned than she would find him stretched out near the temple courtyard gossiping with passing villagers.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'One day, as she was working in the field, trying to dig up the ground so she could sow some seeds, a thin man with a big moustache appeared beside her.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'He was a thief, and up to no good.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Kavery, of course, did not know this.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'She greeted him politely and went back to her work.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Now the thief wanted to steal the coins that were given as offerings in the temple and perhaps even the ornaments on the idol.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'The only way into the temple was by digging his way in from Kavery’s land.',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'But how could he do anything there, with this tough, no-nonsense woman working away?',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Guessing Kavery was hard up for money, he whispered to her,',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘Sister, why are you working so hard on this barren land?',
#   'speaker': 'thief',
#   'emotion': 'neutral'},
#  {'text_chunk': 'I will give you one thousand rupees, sell it to me.',
#   'speaker': 'thief',
#   'emotion': 'neutral'},
#  {'text_chunk': '’', 'speaker': 'thief', 'emotion': 'neutral'},
#  {'text_chunk': 'Kavery raised her eyebrows; why did he want to buy the land for so much money?',
#   'speaker': 'narrator',
#   'emotion': 'surprise'},
#  {'text_chunk': 'Surely something was wrong',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': ' . .', 'speaker': 'narrator', 'emotion': 'neutral'},
#  {'text_chunk': 'The thief sensed she was not about to sell it to him, so he raised his price:',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘A thousand and fifty? No? Two thousand? No again? FIVE THOUSAND? No?’',
#   'speaker': 'thief',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Kavery kept shaking her head..',
#   'speaker': 'narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'She did not like this odd-looking man who was offering her so much money for the field.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Clearly he had some evil plans.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Finally, to keep him quiet, she made up a story.',
#   'speaker': 'Narrator',
#   'emotion': 'neutral'},
#  {'text_chunk': '‘I will never sell this land.',
#   'speaker': 'Kavery',
#   'emotion': 'neutral'},
#  {'text_chunk': 'You see, it belonged to my ancestors.',
#   'speaker': 'Kavery',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Now we are poor, but I am told that once our family was very rich.',
#   'speaker': 'Kavery',
#   'emotion': 'sadness'},
#  {'text_chunk': 'Though we lost a lot of our money, much of it was also buried here, in this field by one ancestor, to keep it safe from robbers.',
#   'speaker': 'Kavery',
#   'emotion': 'neutral'},
#  {'text_chunk': 'Then people forgot about it for years and years.',
#   'speaker': 'Kavery',
#   'emotion': 'neutral'},
#  {'text_chunk': 'My husband found a clue to the location of the hidden treasure just a few days back.',
#   'speaker': 'Kavery',
#   'emotion': 'happiness'},
#  {'text_chunk': 'Why do you think I am digging this hard earth?',
#   'speaker': 'Kavery',
#   'emotion': 'neutral'},
#  {'text_chunk': '
do you think humans will rest with this achievement? Who knows, in a
hundred years what other modes of transport we would have invented so that
we may not require horse for transport at all. Perhaps we will even be able to
fly like birds!’
George never solved this problem in his lifetime. Neither did Adam live to
see how true his thoughts about the future had been. Man went on to invent so
many new ways of moving from place to place that horses are no longer used
in the numbers they once were. James Watt invented the steam engine, which
led to the invention of railways. Then cars were invented by Karl F. Benz and
became widely used in cities for transport. Finally the Wright brothers
showed that humans could fly—in aeroplanes! With all these great inventions,
the horse and other animal-drawn carts and carriages are now a thing of the
past.
Truly, if man did not innovate and experiment, our species would have died
out—just like George had predicted!
Everyone was very happy this story. They all teased Meenu.
‘Y ou are the
George Smith of our house. Who knows one day nobody will eat pappadams
and Amma may not prepare that many pappadams. We may even buy directly
from the shops if it is a small number.
’
Meenu felt very embarrassed. She hid her face with a pillow. Ajji said,
‘Don’t make fun of her. Foresight is very important. If you don’t have
foresight, then you will land up in trouble like Ramu.
’
‘Who is Ramu?’ the children immediately asked Ajji.
‘I will tell the story of Ramu only tomorrow.
’ And Ajji bustled off. The
children knew she would tell only one story a day, so they eagerly waited for
the next day to hear Ramu’s story.
'''

# %%
output_4=pipeline(text_4)
output_4
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-31-8cb49ce86b24> in <cell line: 1>()
# ----> 1 output_4=pipeline(text_4)
#       2 output_4
#
# <ipython-input-24-9688bd89f3ff> in pipeline(text)
#       3   paragraphs = group_sentences_into_paragraphs(sentences)
#       4   ans=generate_annotations(paragraphs)
# ----> 5   return convert_to_json(ans)
#
# <ipython-input-21-f1579e8e0749> in convert_to_json(ans)
#       2   final=[]
#       3   for a in ans:
# ----> 4     dic=json.loads(a)
#       5     for d in dic:
#       6       final.append(d)
#
# /usr/lib/python3.10/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# /usr/lib/python3.10/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /usr/lib/python3.10/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 18 column 19 (char 348)

# %%
text_5='''
Meenu was upset. She pouted and sulked and would not talk to Ajji. But
how can any child be angry with Ajji for very long? Their grandmother was
just too loving and affectionate for anyone to not tell her what was wrong.
‘Ajji, it’s been three days, and you have not told a story about a king yet!’
Meenu grumbled.
Ajji nodded.
‘It’s true, Meenu. That was my fault; I should have told you a
story about a king right away!’
‘And I want a good, nice king, who does good, nice things for his people—
not horrible things like punishing them and jailing them,
’ Meenu sat straight
and demanded.
‘All right, dear. Here’s a king, just as you wanted . . .
’
And Ajji began her story.
King Amrit loved his people and looked after the affairs of his kingdom well.
His minister, Chandan, was a wise man who helped the king in his work
tirelessly.
One day, King Amrit and Chandan were taking a walk on the terrace of the
palace. The terrace offered beautiful views of the surroundings, and they
could see far into the distance. They spotted the weekly market from up there,
with people in colourful clothes buying and selling all kinds of things. There
was plenty to buy and people had money to buy, too. There were no poor
people to be seen anywhere. The king watched with a smile on his face. He
was delighted to see the prosperity of his kingdom. Like any good ruler he
was happy when his people were happy.
He turned to Chandan and said,
‘See how contented my people are. But I
want to check this first-hand by talking to them. Tomorrow, summon people
from all walks of life to the court, and I will ask them myself how they are
doing.
’ Chandan was used to the king’s strange requests, so he nodded and
went off to carry out this order.
The next day, the king arrived in court humming a happy tune to himself.
who was the first to cross the stream after leaving his sack behind seemed to
be unconcerned. Chandan spotted his cheerful face in the crowd and
beckoned him forward. Then he asked,
‘Tell me, are you not sad you had to
leave behind so much of wealth that suddenly came your way?’
The man said,
‘I didn’t pick the jewelled fruits and flowers. I had picked
some of the lovely, tasty fruits and had eaten my fill of them. In my sack I had
kept some others for my little daughter who is at home. I had thought she
would enjoy these tasty apples and mangoes. But when I saw there was no
other way to go across the stream, I did not think twice about leaving my sack
by the river. My little girl can get tasty fruits from some other garden, too!
But I am so happy the king let us all wander around his garden, looking at the
trees and plants and animals. He is a great king for having created this place
of beauty, and it was a pleasure walking around there.
’
Finally a smile appeared on King Amrit’s face. Chandan turned to him and
said,
‘Y our Majesty, I hope you now realize that people’s contentment does
not end with having enough food or money. They also need to be truly happy
inside. Only then will they not be swayed when they gain or lose wealth. That
is a lesson that everyone—whether a king or a commoner—needs to
remember.
’
The king nodded, as did his subjects. This was a lesson they would not
forget in a hurry!
‘Did you like the story, Meenu?’ Raghu asked.
‘Oh yes,
’ Meenu nodded.
‘But I liked the minister more than the king!’
‘That’s true, Meenu,
’ Ajji agreed.
‘Kings did need intelligent ministers to
show them the right path sometimes. Remember Akbar had Birbal, and
Krishnadevaraya had Tenali Rama? Why just kings, we all need someone to
tell us if what we are doing is wrong. It could be our parents, grandparents,
teachers or even our best friend. The important thing is to listen to them and
change our ways when needed.
'''

# %%
output_5=pipeline(text_5)
output_5

# %%
# NOTE: pip shows imcompatible errors due to preinstalled libraries but you do not need to care
# !pip install -q  numpy==1.26.0 protobuf==3.20.2 espnet==202308 pypinyin==0.44.0 parallel_wavegan==0.5.4 gdown==4.4.0 espnet_model_zoo

# %%
#@title Choose English model { run: "auto" }
lang = 'English'
tag = 'kan-bayashi/ljspeech_vits' #@param ["kan-bayashi/ljspeech_tacotron2", "kan-bayashi/ljspeech_fastspeech", "kan-bayashi/ljspeech_fastspeech2", "kan-bayashi/ljspeech_conformer_fastspeech2", "kan-bayashi/ljspeech_joint_finetune_conformer_fastspeech2_hifigan", "kan-bayashi/ljspeech_joint_train_conformer_fastspeech2_hifigan", "kan-bayashi/ljspeech_vits"] {type:"string"}
vocoder_tag = "none" #@param ["none", "parallel_wavegan/ljspeech_parallel_wavegan.v1", "parallel_wavegan/ljspeech_full_band_melgan.v2", "parallel_wavegan/ljspeech_multi_band_melgan.v2", "parallel_wavegan/ljspeech_hifigan.v1", "parallel_wavegan/ljspeech_style_melgan.v1"] {type:"string"}

# %%
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

text2speech = Text2Speech.from_pretrained(
    model_tag=str_or_none(tag),
    vocoder_tag=str_or_none(vocoder_tag),
    device="cuda",
    # Only for Tacotron 2 & Transformer
    threshold=0.5,
    # Only for Tacotron 2
    minlenratio=0.0,
    maxlenratio=10.0,
    use_att_constraint=False,
    backward_window=1,
    forward_window=3,
    # Only for FastSpeech & FastSpeech2 & VITS
    speed_control_alpha=1.0,
    # Only for VITS
    noise_scale=0.333,
    noise_scale_dur=0.333,
)
